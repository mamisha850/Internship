# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
from selenium .webdriver.common.by import By
import pandas as pd
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re
 
import warnings 
warnings.filterwarnings("ignore")

# %%
# Ques1.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.amazon.in/'
driver.get(url)

user_input=input("Enter the product you want to searched:")

search_bar = driver.find_element(By.ID,"twotabsearchtextbox")
search_bar.send_keys(user_input)

search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

time.sleep(5)

# Ques2.

start=0
end=3

brand=[]
for page in range(0,3):
    brand_tag=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in brand_tag:
        brand.append(i.text)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]')  
brands=brand[:186]

name=[]    
for page in range(0,3):
    name_tag=driver.find_elements(By.XPATH,'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in name_tag:
        name.append(i.text)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]')   
names=name[:186]

price=[]
for page in range(0,3):
    price_tag=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
    for i in price_tag:
        price.append(i.text)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[66]/div/div/span/a[3]')
prices=price[3:189]
    
delivery=[]
for page in range(0,3):
    delivery_tag=driver.find_elements(By.XPATH,'//span[@class="a-color-base a-text-bold"]')
    for i in delivery_tag:
        delivery.append(i.text)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[65]/div/div/span/a[3]')    

url=[]
for page in range(0,3):
    url_tag=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url_tag:
        url.append(i.get_attribute("href"))
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[66]/div/div/span/a[3]')    
urls=url[:186]
    
Product=pd.DataFrame({'Brand Name':brands,'Product Name':names,'Price':prices,'Expected Delivery':delivery,'Product url':urls}) 
Product
# Out:
#                                             Brand Name  \
# 0    Kadence Frontier Series, Acoustic Guitar With/...
# 1    Kadence Frontier Jumbo Semi Acoustic Guitar Wi...
# 2    Photron Acoustic Guitar, 38 inches Cutaway, PH...
# 3    Blueberry 38C, 38" Acoustic Guitar Kit with Ba...
# 4    Intern INT-38C Acoustic Guitar Kit, With Bag, ...
# ..                                                 ...
# 181  Juarez JRZ-ST01, 6 Strings Electric Guitar, Ri...
# 182  Hovner Carlton Special Quality Rosewood Fretbo...
# 183  Revel 38 Inches Cutaway Design Acoustic Guitar...
# 184  Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 ...
# 185  AUREUS 4 String Acoustic Guitar Musical Instru...
#
#                                           Product Name  Price  \
# 0    Kadence Frontier Series, Acoustic Guitar With/...  4,799
# 1    Kadence Frontier Jumbo Semi Acoustic Guitar Wi...  6,899
# 2    Photron Acoustic Guitar, 38 inches Cutaway, PH...  2,490
# ...

# %%
# Ques3.

# download fruits
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')
url='http://images.google.com/'
driver.get(url)
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')   
search.send_keys('fruits')
search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
img=[]
for image in images:
    source=image.get_attribute('src')
for i in range(len(img)):
    if i > 10:
        break
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img[i])
    file = open(r"path"+str(i)+".jpg","wb")
    file.write(response.content)

# Download cars    
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')
url='http://images.google.com/'
driver.get(url)
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')   
search.send_keys('cars')
search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
img=[]
for image in images:
    source=image.get_attribute('src')
for i in range(len(img)):
    if i > 10:
        break
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img[i])
    file = open(r"path"+str(i)+".jpg","wb")
    file.write(response.content)

# Download Machine Learning
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')
url='http://images.google.com/'
driver.get(url)
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')   
search.send_keys('Machine Learning')
search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
img=[]
for image in images:
    source=image.get_attribute('src')
for i in range(len(img)):
    if i > 10:
        break
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img[i])
    file = open(r"path"+str(i)+".jpg","wb")
    file.write(response.content)

# Download Guitars
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')
url='http://images.google.com/'
driver.get(url)
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')   
search.send_keys('Guitar')
search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
img=[]
for image in images:
    source=image.get_attribute('src')
for i in range(len(img)):
    if i > 10:
        break
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img[i])
    file = open(r"path"+str(i)+".jpg","wb")
    file.write(response.content)
    
# download cakes   
driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')
url='http://images.google.com/'
driver.get(url)
for _ in range(20):
    driver.execute_script("window.scrollBy(0,1000)")
search=driver.find_element(By.XPATH,'//input[@class="gLFyf gsfi"]')   
search.send_keys('cakes')
search_button=driver.find_element(By.XPATH,'//span[@class="z1asCe MZy1Rb"]')
search_button.click()
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
img=[]
for image in images:
    source=image.get_attribute('src')
for i in range(len(img)):
    if i > 10:
        break
    print("Downloading {0} of {1} images".format(i,10))
    response=requests.get(img[i])
    file = open(r"path"+str(i)+".jpg","wb")
    file.write(response.content)    
    
# Download all the photos in the the jupyternotebook.

# %%
# Ques4.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='http://www.flipkart.com/'
driver.get(url)

search=driver.find_element(By.CLASS_NAME,"_3704LK")
search.send_keys("Smartphone")

search_button=driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_button.click()

br=[]
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in brand_tags:
    br.append(i.text.split()[0])

nm=[]
name_tags=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in name_tags:
    nm.append(i.text)
    
col=[]
col_tags=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in col_tags:
    col.append(i.text.split()[-3].replace('(',''))
    
ram=[]
ram_tags=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in ram_tags:
    ram.append(i.text.split()[0])
RAM=ram[0:144:6] 

rom=[]
rom_tags=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in rom_tags:
    rom.append(i.text.split()[-2])
    
prm=[]
prm_tags=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in prm_tags:
    prm.append(i.text.split()[0].replace('MP',''))
primary=prm[2:144:6]   

sec=[]
sec_tags=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in sec_tags:
    sec.append(i.text.replace('Front Camera','').split()[-1].replace('MP',''))
secondary=sec[2:144:6]   

disp=[]
disp_tags=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in disp_tags:
    disp.append(i.text.split()[0])
display=disp[1:144:6]

bat=[]
bat_tags=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"]')
for i in bat_tags:
    bat.append(i.text.split()[0])
battery=bat[3:144:6] 

price=[]
pr_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
for i in pr_tags:
    price.append(i.text.replace('₹',''))  
    
url=[]
url_tags=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url_tags:
    url.append(i.get_attribute("href"))
    
    
Smartphone=pd.DataFrame({'Brand Name':br,'Smartphone name':nm,'Colour':col,'RAM':RAM,'ROM':rom,'Primary Camera':primary,
                        'Secondary Camera':secondary,'Dispaly Size':display,'Battery Capacity':battery,'Price':price,
                         'Product URL':url})
Smartphone    

#save Smartphone dataframe in csv form at the given location

Smartphone.to_csv('C:\Users\Dell\Desktop\Files\Smartphone.csv',index=False)
# Out:
#    Brand Name                              Smartphone name   Colour   RAM  \
# 0        POCO                 POCO C31 (Royal Blue, 64 GB)    Blue,     4
# 1        POCO                POCO C31 (Shadow Gray, 64 GB)    Gray,     4
# 2        POCO                 POCO C31 (Royal Blue, 32 GB)    Blue,     3
# 3       REDMI               REDMI 10 (Pacific Blue, 64 GB)    Blue,     4
# 4       APPLE              APPLE iPhone 12 (Black, 128 GB)   Black,   128
# 5       REDMI          REDMI 9i Sport (Coral Green, 64 GB)   Green,   All
# 6     Infinix    Infinix HOT 12 Play (Racing Black, 64 GB)   Black,  5000
# 7       REDMI         REDMI 9i Sport (Carbon Black, 64 GB)   Black,  6000
# 8       REDMI             REDMI 10 (Midnight Black, 64 GB)   Black,  5000
# 9       REDMI        REDMI 9i Sport (Metallic Blue, 64 GB)    Blue,  6000
# 10    SAMSUNG   SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)   Green,  5000
# 11     Realme         Realme Narzo 50i (Mint Green, 64 GB)   Green,  6000
# ...

# %%
# Ques5.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.google.com/maps/'
driver.get(url)

search_tags=driver.find_element(By.ID,"searchboxinput")
search_tags.send_keys('Delhi')   

search=driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')
search.click()
 
try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.com/maps/place/Delhi/@28.6466772,76.8130673,10z/data=!3m1!4b1!4m5!3m4!1s0x390cfd5b347eb62d:0x37205b715389640!8m2!3d28.7040592!4d77.1024902
# Latitude = 28.6466772, Longitude = 76.8130673

# %%
# Ques6.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://trak.in/'
driver.get(url)

funding_deal=driver.find_element(By.XPATH,'/html/body/div[1]/header/div[2]/div/div/div/div/nav/ul/li[9]/a')
funding_deal.click()

time.sleep(6)

sr=[]
serial=driver.find_elements(By.XPATH,'//td[@class="column-1"]')
for i in serial:
    sr.append(i.text)
sr_no= sr[5:29]

dt=[]
date_tag=driver.find_elements(By.XPATH,'//td[@class="column-2"]')
for i in date_tag:
    dt.append(i.text)
date= dt[5:29]

st=[]
st_tag=driver.find_elements(By.XPATH,'//td[@class="column-3"]')
for i in st_tag:
    st.append(i.text)
startup= st[5:29]

Ind=[]
Ind_tag=driver.find_elements(By.XPATH,'//td[@class="column-4"]')
for i in Ind_tag:
    Ind.append(i.text)
Industry= Ind[5:29]
Industry

ver=[]
ver_tag=driver.find_elements(By.XPATH,'//td[@class="column-5"]')
for i in ver_tag:
    ver.append(i.text)
vertical= ver[5:29]

loc=[]
loc_tag=driver.find_elements(By.XPATH,'//td[@class="column-6"]')
for i in loc_tag:
    loc.append(i.text)
city= loc[5:29]

nm=[]
name_tag=driver.find_elements(By.XPATH,'//td[@class="column-7"]')
for i in name_tag:
    nm.append(i.text)
name= nm[5:29]

ty=[]
type_tag=driver.find_elements(By.XPATH,'//td[@class="column-8"]')
for i in type_tag:
    ty.append(i.text)
type= ty[5:29]

amt=[]
amt_tag=driver.find_elements(By.XPATH,'//td[@class="column-9"]')
for i in amt_tag:
    amt.append(i.text)
amount= amt[5:29]

Funding_Deals=pd.DataFrame({'Sr.No.':sr_no,'Date':date,'Startup Name':startup,'Industry':Industry,'Sub Vertical':vertical,
                           'Location/City':city,'Investor Name':name,'Investor Type':type,'Amount':amount})
Funding_Deals
# Out:
#    Sr.No.        Date            Startup Name                Industry  \
# 0       1  04/03/2021               DealShare              E-commerce
# 1       2  31/03/2021                Uniphore              Technology
# 2       3  30/03/2021                   Dunzo              E-commerce
# 3       4  30/03/2021                  BYJU’S                Edu-tech
# 4       5  23/03/2021             SkilloVilla                Edu-tech
# 5       6  25/03/2021                CityMall              E-commerce
# 6       7  26/03/2021                   DotPe                 FinTech
# 7       1  11/02/2021                Doubtnut                Edu Tech
# 8       2  22/02/2021                  Zomato             Hospitality
# 9       3  19/02/2021               Fingerlix             Hospitality
# 10      4  17/02/2021                   Zolve                 FinTech
# 11      5  15/02/2021               KreditBee                 Finance
# ...

# %%
# Ques7.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.digit.in/top-products/best-gaming-laptops-40.html'
driver.get(url)

name_tags=driver.find_elements(By.XPATH,'//div[@class="TopNumbeHeading active sticky-footer"]')
name=[]
for i in name_tags:
    name.append(i.text.replace('\n',''))

display_tags=driver.find_elements(By.XPATH,'//div[@class="Wrap-pop"]')
display=[]
for i in display_tags:
    display.append(i.text.split()[0].replace('"',''))
displays=display[1:40:4]

pro_tags=driver.find_elements(By.XPATH,'//div[@class="Wrap-pop"]')
pro=[]
for i in pro_tags:
    pro.append(i.text.split()[-3].replace('|','NaN'))
processor=pro[2:40:4]

sd_tags=driver.find_elements(By.XPATH,'//div[@class="Wrap-pop"]')
sd=[]
for i in sd_tags:
    sd.append(i.text.split()[0])
ssd=sd[3:40:4]

mem_tags=driver.find_elements(By.XPATH,'//div[@class="Wrap-pop"]')
mem=[]
for i in mem_tags:
    mem.append(i.text.split()[2].replace('SSD/','').replace('NVME/',''))
memory=mem[3:40:4]

bd_tags=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]')
bd=[]
for i in bd_tags:
    bd.append(i.text.split()[-3])
weight=bd[:]

sell_tags=driver.find_elements(By.XPATH,'//td[@class="smmerchant"]')
seller=[]
for i in sell_tags:
    seller.append(i.text.replace('N/A','NAN'))

pr_tags=driver.find_elements(By.XPATH,'//td[@class="smprice"]')
price=[]
for i in pr_tags:
    price.append(i.text.replace('₹','').replace('N/A','NaN'))

Laptop=pd.DataFrame({'Name':name,'Display':displays,'Processor':processor,'SSD':ssd,'Memory':memory,'Body weight':weight,
                     'Seller':seller,'Price':price})
Laptop
# Out:
#                                               Name Display Processor  SSD  \
# 0                           1.MSI TITAN GT77-12UHS    17.3       NaN    2
# 1                               2.ALIENWARE X17 R2    17.3      5.00    1
# 2          3.ACER PREDATOR TRITON 500 SE PT516-52S      16      3.50    2
# 3                        4.OMEN BY HP (16-B1371TX)    16.1       4.7    1
# 4  5.ACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0    15.6       NaN  512
# 5                     6.MSI DELTA 15 (A5EFK-083IN)    15.6       NaN    1
# 6                        7.OMEN BY HP (16-C0141AX)    16.1       3.3    1
# 7              8.LENOVO LEGION 5I PRO (82RF00MGIN)      16      3.50    1
# 8  9.ALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN    15.6      4.40  512
# 9              10.LENOVO SLIM 7 GEN 6 (82K8002JIN)    15.6       3.2    1
#
#   Memory Body weight  Seller     Price
# 0     64         3.3     NAN       NaN
# 1     32        3.02    Dell   389,990
# ...

# %%
# Ques8.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.forbes.com/billionaires/'
driver.get(url)

rank_tags=driver.find_elements(By.XPATH,'//div[@class="rank"]')
rank=[]
for i in rank_tags:
    rank.append(i.text.replace('.',''))
    
name_tags=driver.find_elements(By.XPATH,'//div[@class="personName"]')
name=[]
for i in name_tags:
    name.append(i.text)
    
worth_tags=driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
net_worth=[]
for i in worth_tags:
    net_worth.append(i.text.split()[0].replace('$',''))
    
age_tags=driver.find_elements(By.XPATH,'//div[@class="age"]')
age=[]
for i in age_tags:
    age.append(i.text)    

citizenship_tags=driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
citizenship=[]
for i in citizenship_tags:
    citizenship.append(i.text)
    
source_tags=driver.find_elements(By.XPATH,'//div[@class="source"]')
source=[]
for i in source_tags:
    source.append(i.text)    
    
industry_tags=driver.find_elements(By.XPATH,'//div[@class="category"]')
industry=[]
for i in industry_tags:
    industry.append(i.text)    

Billionaries=pd.DataFrame({'Rank':rank,'Name':name,'Net Worth(in Billion)':net_worth,'Age':age,'Citizenship':citizenship,
                          'Source':source,'Industry':industry})
Billionaries
# Out:
#     Rank                      Name Net Worth(in Billion) Age    Citizenship  \
# 0      1                 Elon Musk                   219  50  United States
# 1      2                Jeff Bezos                   171  58  United States
# 2      3  Bernard Arnault & family                   158  73         France
# 3      4                Bill Gates                   129  66  United States
# 4      5            Warren Buffett                   118  91  United States
# ..   ...                       ...                   ...  ..            ...
# 195  192    Marcel Herrmann Telles                  10.3  72         Brazil
# 196  197                Leon Black                    10  70  United States
# 197  197                Joe Gebbia                    10  40  United States
# 198  197              David Geffen                    10  79  United States
# 199  197                Yu Renrong                    10  56          China
#
#                     Source               Industry
# ...

# %%
# Ques9.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# facebook Live video with mukesh ambani 
url='https://www.youtube.com/watch?v=uumdAlVFUc0'
driver.get(url)

com_tag=driver.find_elements(By.XPATH,'//yt-formatted-string[@id="content-text"]')
comment=[]
for i in com_tag:
    comment.append(i.text)
    
vt_tag=driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
vote=[]
for i in vt_tag:
    vote.append(i.text)
    
tm_tag=driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
time=[]
for i in tm_tag:
    time.append(i.text.replace('(edited)',''))
times=time[7:547]      

you_tube=pd.DataFrame({'Comment':comment,'Comment upvote':vote,'Time':times})
you_tube
# Out:
#                                                Comment Comment upvote  \
# 0    Hats off to Mukesh for this Savage reply to th...           3.4K
# 1    Rajdeep :- aap 25 saal k hote mukesh bhai tab ...           4.7K
# 2    THE RICHEST PERSON IN INDIA IS SO HUMBLE AND G...           1.6K
# 3    0:21 he literally killed interviewer with this...            768
# 4    " My role model is my father "\n       - Such ...            260
# ..                                                 ...            ...
# 535  Desai ji before asking any question to such pe...
# 536                                # ambani ka swag op
# 537  his brother anil Ambani is a pretty good speak...              5
# 538  Isse kehte hai muh pe thookna.......mukesh amb...
# 539  अंबानी भैया को गर्दन में समस्या है बहुत हिला र...            463
#
#              Time
# 0      1 year ago
# 1     2 years ago
# 2     2 years ago
# 3      1 year ago
# 4            0:21
# ..            ...
# 535          6:04
# ...

# %%
# Ques10.

#driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

#url='http://www.hostelworld.com/'
#driver.get(url)

#search_loc = driver.find_element(By.ID,"search-input-field")
#search_loc.send_keys("London")

#select_loc=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div")
#select_loc.click()

#got_it=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button')
#got_it.click()

name_tags=driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
nm=[]
for i in name_tags:
    nm.append(i.text)
name=nm[:16]  

dist_tags=driver.find_elements(By.XPATH,'//span[@class="description"]')
dist=[]
for i in dist_tags:
    dist.append(i.text.split()[2].replace('km','').replace('Breakfast','4.2'))
distance=dist[:16]
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
rt=[]
for i in rate_tags:
    rt.append(i.text)
rate=rt[:16]    

price_tags=driver.find_elements(By.XPATH,'//div[@class="price title-5"]')
private=[]
for i in price_tags:
    private.append(i.text.split()[0].replace('Rs',''))
private_price=private[1:56:2]

dorms_tags=driver.find_elements(By.XPATH,'//div[@class="price title-5"]')
dorms=[]
for i in dorms_tags:
    dorms.append(i.text.split()[-1].replace('Rs',''))
dorms_price=dorms[0:16]

total_tags=driver.find_elements(By.XPATH,'//div[@class="reviews"]')
tot=[]
for i in total_tags:
    tot.append(i.text.split()[0])
total=tot[:16]

Hostel=pd.DataFrame({'Hostel name':name,'Distance from city centre':distance,'Ratings':rate,'total reviews':total,
                    'Privates from price':private_price,'Dorms from price':dorms_price})
Hostel
# Out:
#                                 Hostel name Distance from city centre Ratings  \
# 0                  St Christopher's Village                       1.8     8.1
# 1                             Selina Camden                       5.5     8.6
# 2               Wombat's City Hostel London                       3.6     9.1
# 3                          Generator London                         3     7.7
# 4                      Urbany Hostel London                       5.4     9.3
# 5         Safestay London Elephant & Castle                       1.7     7.1
# 6                   Smart Camden Inn Hostel                       4.4     8.4
# 7                        No.8 Seven Sisters                         9     6.2
# 8   Safestay London Kensington Holland Park                       5.9     6.5
# 9                            Phoenix Hostel                       4.2     7.6
# 10                         NX London Hostel                       6.1     7.3
# ...
