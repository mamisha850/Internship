# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
from selenium .webdriver.common.by import By
import pandas as pd
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re
 
import warnings 
warnings.filterwarnings("ignore")

# %%
# Ques1.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

#                                        Scrap the Data

rank_tags=driver.find_elements(By.XPATH,'//td[@align="center"]')
r=[]
for i in rank_tags:
    r.append(i.text.replace('.',''))
rank1=r[0:34:3]
rank2=r[35:70:2]
rank=rank1+rank2

name_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')
name=[]
for i in name_tags:
    name.append(i.text)
    
artist_tags=driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')
artist=[]
for i in artist_tags:
    artist.append(i.text)

date_tags=driver.find_elements(By.XPATH,'//td[@align="right"]')
d=[]
for i in date_tags:
    d.append(i.text)
date=d[:30]

view_tags=driver.find_elements(By.XPATH,'//td[@align="center"]')
v=[]
for i in view_tags:
    v.append(i.text)
view1=r[1:35:3]
view2=r[36:71:2]
view=view1+view2

#                                    Create data frame

Video=pd.DataFrame({'Rank':rank,'Name':name,'Artist':artist,'Upload Date':date,'Views':view})
Video
# Out:
#    Rank                                             Name  \
# 0     1                            "Baby Shark Dance"[3]
# 1     2                                   "Despacito"[6]
# 2     3                       "Johny Johny Yes Papa"[12]
# 3     4                               "Shape of You"[13]
# 4     5                              "See You Again"[15]
# 5     6                                  "Bath Song"[20]
# 6     7                "Phonics Song with Two Words"[21]
# 7     8                                "Uptown Funk"[22]
# 8     9  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9    10                              "Gangnam Style"[24]
# 10   11   "Masha and the Bear – Recipe for Disaster"[29]
# 11   12                          "Wheels on the Bus"[30]
# 12   13                             "Dame Tu Cosita"[31]
# 13   14                                      "Sugar"[32]
# 14   15                                       "Roar"[33]
# ...

# %%
# Ques2.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='http://www.bcci.tv/'
driver.get(url)

time.sleep(5)

#                                reach international fixture

inter_tags=driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
inter_tags.click()

#                                         scrap details

match_tags=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]')
m=[]
for i in match_tags:
    m.append(i.text.split()[0:2])
    
series_tags=driver.find_elements(By.XPATH,'//h5[@class="fix-text"]')
s=[]
for i in series_tags:
    s.append(i.text)
series=s[1:16:2]    

place_tags=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]')
p=[]
for i in place_tags:
    p.append(i.text.replace('1st','').replace('2nd','').replace('3rd','').replace('ODI','').replace('T20I','').replace('-',''))

date_tags=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
d=[]
for i in date_tags:
    d.append(i.text)
    
time_tags=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
t=[]
for i in time_tags:
    t.append(i.text.replace('IST',''))
    
#                                      Create Data Frame 

Match=pd.DataFrame({'Match title':m,'Series':series,'Place':p,'Date':d,'Time(in IST)':t})
Match
# Out:
#    Match title                                   Series  \
# 0   [1st, ODI]   INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 1   [2nd, ODI]   INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 2   [3rd, ODI]   INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 3  [1st, T20I]                            ASIA CUP 2022
# 4  [2nd, T20I]                            ASIA CUP 2022
# 5  [1st, T20I]  AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 6  [2nd, T20I]  AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 7  [3rd, T20I]  AUSTRALIA TOUR OF INDIA T20 SERIES 2022
#
#                                                Place         Date Time(in IST)
# 0                         Harare Sports Club, Harare  18 AUG 2022    12:45 PM
# 1                         Harare Sports Club, Harare  20 AUG 2022    12:45 PM
# 2                         Harare Sports Club, Harare  22 AUG 2022    12:45 PM
# 3         Dubai International Cricket Stadium, Dubai  28 AUG 2022     7:30 PM
# ...

# %%
#Ques3.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='http://www.guru99.com/'
driver.get(url)

time.sleep(5)

#                              Select Selenium and then reach Selenium Exception Handling

selenium=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a')
selenium.click()

excep_handling=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a/strong')
excep_handling.click()

time.sleep(10)

#                                       Scrap the details

name_tags=driver.find_elements(By.XPATH,'//table[@class="table table-striped"][1]/tbody/tr/td[1]')
name=[]
for i in name_tags:
    name.append(i.text)
    
descp_tags=driver.find_elements(By.XPATH,'//table[@class="table table-striped"][1]/tbody/tr/td[2]')
descp=[]
for i in descp_tags:
    descp.append(i.text)    
    
#                                    Create Data Frame

Selenium_Exception_Handling=pd.DataFrame({'Name':name,'Description':descp})
Selenium_Exception_Handling
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
#Ques4.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='http://statisticstimes.com/'
driver.get(url)

time.sleep(5)

#                                  Select economy then GDP of India

economy=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy.click()

India=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
India.click()

selectGDP_tag=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
selectGDP_tag.click() 

time.sleep(10)

#                                     Scrap the data

rank_tags=driver.find_elements(By.XPATH,'//td[@class="data1"]')
r=[]
for i in rank_tags:
    r.append(i.text)
rank=r[0:33]

state_tags=driver.find_elements(By.XPATH,'//td[@class="name"]')
s=[]
for i in state_tags:
    s.append(i.text)
state=s[0:33]

gsdp_tags=driver.find_elements(By.XPATH,'//td[@class="data"]')
g=[]
for i in gsdp_tags:
    g.append(i.text)
gsdp=g[0:165:5]

GSDP_tags=driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]')
G=[]
for i in GSDP_tags:
    G.append(i.text)
GSDP=G[0:33]

share_tags=driver.find_elements(By.XPATH,'//td[@class="data"]')
sh=[]
for i in share_tags:
    sh.append(i.text.replace('%',''))
share=sh[1:165:5]

gdp_tags=driver.find_elements(By.XPATH,'//td[@class="data"]')
gd=[]
for i in gdp_tags:
    gd.append(i.text)
gdp=gd[2:165:5]

#                                        Create Data Frame

GDP_of_India=pd.DataFrame({'Rank':rank,'State':state,' GSDP(19-20)':gsdp,'GSDP(18-19)':GSDP,'Share(2018)(in %)':share,
                           'GDP($ billion)':gdp})
GDP_of_India
# Out:
#    Rank                      State  GSDP(19-20) GSDP(18-19) Share(2018)(in %)  \
# 0     1                Maharashtra            -   2,632,792             13.94
# 1     2                 Tamil Nadu    1,845,853   1,630,208              8.63
# 2     3              Uttar Pradesh    1,687,818   1,584,764              8.39
# 3     4                    Gujarat            -   1,502,899              7.96
# 4     5                  Karnataka    1,631,977   1,493,127              7.91
# 5     6                West Bengal    1,253,832   1,089,898              5.77
# 6     7                  Rajasthan    1,020,989     942,586              4.99
# 7     8             Andhra Pradesh      972,782     862,957              4.57
# 8     9                  Telangana      969,604     861,031              4.56
# 9    10             Madhya Pradesh      906,672     809,592              4.29
# 10   11                     Kerala            -     781,653              4.14
# ...

# %%
#Ques5.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://github.com/'
driver.get(url)

time.sleep(5)

#                                      Click the trending option 

explore=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
explore.click()

trending=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
trending.click()

#                                      Scrap the details

title_tags=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
title=[]
for i in title_tags:
    title.append(i.text)
    
descrip_tags=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
d=[]
for i in descrip_tags:
        d.append(i.text)
d.insert(14,'-')        
        
count_tags=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
c=[]
for i in count_tags:
    c.append(i.text)
count=c[0:50:2]

lang_tags=driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]')
l=[]
for i in lang_tags:
    l.append(i.text.split()[0].replace('228,552','-').replace('7,670','-').replace('167','-').replace('244,271','-'))
    
#                                        Create Data Frame

Repository=pd.DataFrame({'Repository title':title,'Repository description':d,'Contributors count':count,'Language used':l})
Repository
# Out:
#                               Repository title  \
# 0                        toeverything / AFFiNE
# 1        jwasham / coding-interview-university
# 2                              iptv-org / iptv
# 3                              ventoy / Ventoy
# 4                      MarlinFirmware / Marlin
# 5                            Dreamacro / clash
# 6                    arthurspk / guiadevbrasil
# 7           donnemartin / system-design-primer
# 8                            MatrixTM / MHDDoS
# 9                       t3-oss / create-t3-app
# 10                   punk-security / dnsReaper
# 11  juliocesarfort / public-pentesting-reports
# 12                   facebookresearch / ParlAI
# 13                                utmapp / UTM
# 14             theboy181 / switch-ptchtxt-mods
# 15                 Asabeneh / 30-Days-Of-React
# 16                               github / docs
# 17     josephmisiti / awesome-machine-learning
# 18             PKUFlyingPig / cs-self-learning
# ...

# %%
#Ques6.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.billboard.com/'
driver.get(url)

time.sleep(5)

#                                  Click charts option and then hot 100

explore=driver.find_element(By.XPATH,'//div[@class="lrv-u-flex lrv-u-justify-content-start lrv-u-margin-lr-050@mobile-max"]')
explore.click() 

chart_tag=driver.find_element(By.XPATH,'/html/body/div[3]/div[6]/div/div/div/ul/li[1]/h3/button')
chart_tag.click()

hot_100=driver.find_element(By.XPATH,'/html/body/div[3]/div[6]/div/div/div/ul/li[1]/ul/li[2]/a')
hot_100.click()

time.sleep(10)

#                                         Scrap the data

song_tags=driver.find_elements(By.XPATH,'//h3[@id="title-of-a-story"]')
s=[]
for i in song_tags:
    s.append(i.text)
song=s[6:406:4] 

x=driver.find_element(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet"]')
x.text
artist_tags=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
a=[]
for i in artist_tags:
    a.append(i.text)
a.insert(0,'Lizzo')

last_tags=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
lr=[]
for i in last_tags:
    lr.append(i.text)
last_rank=lr[0:200:2]

peak_tags=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]')
pr=[]
for i in peak_tags:
    pr.append(i.text.split()[-2])
    
weeks_tags=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
w=[]
for i in weeks_tags:
    w.append(i.text)
weeks=w[1:200:2]

#                                   Create Data Frame

billboard=pd.DataFrame({'Song name':song,'Artist name':a,'Last week rank':last_rank,'Peak rank':pr,'Weeks on board':weeks})
billboard
# Out:
#                                  Song name                    Artist name  \
# 0                          About Damn Time                          Lizzo
# 1                                As It Was                   Harry Styles
# 2   Running Up That Hill (A Deal With God)                      Kate Bush
# 3                              First Class                    Jack Harlow
# 4                               Wait For U  Future Featuring Drake & Tems
# ..                                     ...                            ...
# 95                             Te Felicito       Shakira & Rauw Alejandro
# 96                     Are You Entertained              Russ & Ed Sheeran
# 97            Bzrp Music Sessions, Vol. 52             Bizarrap & Quevedo
# 98                                Right On                       Lil Baby
# 99                            La Corriente          Bad Bunny & Tony Dize
#
#    Last week rank Peak rank Weeks on board
# ...

# %%
# Ques7:

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.naukri.com/hr-recruiters-consultants'
driver.get(url)

time.sleep(5)

search_tab=driver.find_element(By.CLASS_NAME,"sugInp")
search_tab.send_keys("Data science")

search=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
search.click()

#                                Scrap data 

name_tags=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
n=[]
for i in name_tags:
    n.append(i.text)
    
desig_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
d=[]
for i in desig_tags:
    d.append(i.text)
    
comp_tags=driver.find_elements(By.XPATH,'//a[@class="ellipsis"]')
c=[]
for i in comp_tags:
    c.append(i.text)
comp=c[1:100:2]   

skill_tags=driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')
s=[]
for i in skill_tags:
    s.append(i.text)
    
loc_tags=driver.find_elements(By.XPATH,'//p[@class="highlightable"]')
l=[]
for i in loc_tags:
    l.append(i.text.split()[-1].replace('(london)','UK-(london)').replace('Corp','NaN').replace('City','Salt Lake City').replace
             ('Granular.ai','NaN'))
location=l[:]

#                              Create Data frame

Data=pd.DataFrame({'Name':n,'Designation':d,'Company':comp,'Skills they hire for':s,'Location':location})
Data
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Vaishnavi Kudalkar
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %%
# Ques8.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

#                                           Scrap the data

book_tags=driver.find_elements(By.XPATH,'//td[@class="left"]')
b=[]
for i in book_tags:
    b.append(i.text)
book=b[1:500:5]

author_tags=driver.find_elements(By.XPATH,'//td[@class="left"]')
a=[]
for i in author_tags:
    a.append(i.text)
author=a[2:500:5]

volume_tags=driver.find_elements(By.XPATH,'//td[@class="left"]')
v=[]
for i in volume_tags:
    v.append(i.text.replace(',',''))
volume=v[3:500:5]

pub_tags=driver.find_elements(By.XPATH,'//td[@class="left"]')
p=[]
for i in pub_tags:
    p.append(i.text)
publisher=p[4:500:5]

gen_tags=driver.find_elements(By.XPATH,'//td[@class="last left"]')
g=[]
for i in gen_tags:
    g.append(i.text)
genre=g[:]

#                                                Create DataFrame

SellingBooks=pd.DataFrame({'Book name':book,'Author name':author,'Volumes sold':volume,'Publisher':publisher,
                           'Genre':genre})
SellingBooks
# Out:
#                                             Book name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
# Ques9.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='http://www.imdb.com/list/ls095964455/'
driver.get(url)

time.sleep(8)

#                               Scrap the data

name_tags=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
n=[]
for i in name_tags:
    n.append(i.text.replace(')','').split()[1:-1])
    
year_tags=driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
y=[]
for i in year_tags:
    y.append(i.text.replace('(','').replace(')',''))
    
genre_tags=driver.find_elements(By.XPATH,'//span[@class="genre"]')
g=[]
for i in genre_tags:
    g.append(i.text)
    
time_tags=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
t=[]
for i in time_tags:
    t.append(i.text.replace('min',''))
    
rate_tags=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
r=[]
for i in rate_tags:
    r.append(i.text)
    
vote_tags=driver.find_elements(By.XPATH,'//span[@name="nv"]')
v=[]
for i in vote_tags:
    v.append(i.text.replace(',',''))
    
#                                    Create Data Frame

SeriesData=pd.DataFrame({'Name':n,'Year span':y,'Genre':g,'Run time(min)':t,'Rating':r,'Votes':v})
SeriesData
# Out:
#                                     Name  Year span                     Genre  \
# 0                    [Game, of, Thrones]  2011–2019  Action, Adventure, Drama
# 1                     [Stranger, Things]     2016–     Drama, Fantasy, Horror
# 2                   [The, Walking, Dead]  2010–2022   Drama, Horror, Thriller
# 3                     [13, Reasons, Why]  2017–2020  Drama, Mystery, Thriller
# 4                             [The, 100]  2014–2020    Drama, Mystery, Sci-Fi
# ..                                   ...        ...                       ...
# 95                               [Reign]  2013–2017                     Drama
# 96  [A, Series, of, Unfortunate, Events]  2017–2019  Adventure, Comedy, Drama
# 97                     [Criminal, Minds]  2005–2020     Crime, Drama, Mystery
# 98            [Scream:, The, TV, Series]  2015–2019      Comedy, Crime, Drama
# 99      [The, Haunting, of, Hill, House]       2018    Drama, Horror, Mystery
#
#    Run time(min) Rating    Votes
# ...

# %%
# Ques10.

driver = webdriver.Chrome(r'C:\Users\Dell\Downloads\chromedriver_win32 (1)\chromedriver.exe')

url='https://archive.ics.uci.edu/'
driver.get(url)

time.sleep(5)

#                                         Search all the dataset

all_dataset_select=driver.find_element(By.XPATH,'/html/body/table[2]/tbody/tr/td/span/b/a')
all_dataset_select.click()


#                                      Scrap all the necessary details

name_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
n=[]
for i in name_tags:
    n.append(i.text)
name=n[8:4362:7] 

type_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
t=[]
for i in type_tags:
    t.append(i.text)
typee=t[9:4362:7] 

task_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
ta=[]
for i in task_tags:
    ta.append(i.text)
task=ta[10:4362:7] 

atype_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
at=[]
for i in atype_tags:
    at.append(i.text)
at_type=at[11:4362:7]

instance_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
ins=[]
for i in instance_tags:
    ins.append(i.text)
instance=ins[12:4362:7] 

attribute_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
att=[]
for i in attribute_tags:
    att.append(i.text)
attribute=att[13:4362:7]

year_tags=driver.find_elements(By.XPATH,'//p[@class="normal"]')
y=[]
for i in year_tags:
    y.append(i.text)
year=y[14:4362:7]

#                                              Create Data Frame

DataSet=pd.DataFrame({'Dataset name':name,'Data type':typee,'Task':task,'Attribute type':at_type,'No of instances':instance,
                     'No of attribute':attribute,'Year':year})
DataSet
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
